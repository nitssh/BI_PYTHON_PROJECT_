# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r'G:\Python\Pipili_110_AE_2009.xlsx')
df.head()
# Out:
#   SL.NO. OF\rPOLLING\rSTATIONS  AJIT\nMANGARAJ\INC  PRADEEP\nMAHARATHY\BJD\n  \
# 0                            1                  76                       749
# 1                            2                  80                       725
# 2                            3                  20                       179
# 3                            4                  30                       386
# 4                            5                  28                       368
#
#    JUDHISTIR\nSAMANTARA\nY\INC  ASHOK\nPRADHAN\BJP  SUDARSHAN\nPRADHAN\SP  \
# 0                          434                   4                      2
# 1                          262                   6                      3
# 2                          270                   3                      5
# 3                          292                   8                      2
# 4                           69                   2                      1
#
#    SHYAM\rSUNDAR\rCHHOTRYA  Total of Valid\rVotes  No of\rrejected\rvotes  \
# 0                       11                   1276                     NaN
# 1                        5                   1081                     NaN
# 2                        9                    486                     NaN
# 3                        5                    723                     NaN
# 4                        2                    470                     NaN
#
#    Total  No of\rtendered\rvotes
# 0   1276                     NaN
# 1   1081                     NaN
# 2    486                     NaN
# 3    723                     NaN
# 4    470                     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
# STATIONS  236 non-null    object
#  1   AJIT
# MANGARAJ\INC           236 non-null    int64
#  2   PRADEEP
# MAHARATHY\BJD
#       236 non-null    int64
#  3   JUDHISTIR
# SAMANTARA
# Y\INC   236 non-null    int64
#  4   ASHOK
# PRADHAN\BJP           236 non-null    int64
#  5   SUDARSHAN
# PRADHAN\SP        236 non-null    int64
# CHHOTRYA       236 non-null    int64
# Votes        236 non-null    int64
# votes        3 non-null      float64
#  9   Total                       236 non-null    int64
# votes        3 non-null      float64
# dtypes: float64(2), int64(8), object(1)
# memory usage: 20.4+ KB

# %%
df.isnull().sum()
# Out:
# SL.NO. OF\rPOLLING\rSTATIONS      0
# AJIT\rMANGARAJ                    0
# PRADEEP\rMAHARATH\rY              0
# JUDHISTIR\rSAMANTARA\rY           0
# ASHOK\rPRADHAN                    0
# SUDARSHAN\rPRADHAN                0
# SHYAM\rSUNDAR\rCHHOTRYA           0
# Total of Valid\rVotes             0
# No of\rrejected\rvotes          233
# Total                             0
# No of\rtendered\rvotes          233
# dtype: int64

# %%
df.describe()
# Out:
#        AJIT\rMANGARAJ  PRADEEP\rMAHARATH\rY  JUDHISTIR\rSAMANTARA\rY  \
# count      236.000000            236.000000               236.000000
# mean       141.580508            942.050847               783.122881
# std       1019.376917           6779.497479              5636.406125
# min          1.000000             12.000000                 4.000000
# 25%         23.750000            229.750000               171.500000
# 50%         39.500000            311.000000               253.500000
# 75%         63.000000            392.250000               328.250000
# max      11138.000000          74112.000000             61607.000000
#
#        ASHOK\rPRADHAN  SUDARSHAN\rPRADHAN  SHYAM\rSUNDAR\rCHHOTRYA  \
# count      236.000000          236.000000               236.000000
# mean        17.618644            7.220339                25.355932
# std        127.180048           52.013768               183.196117
# min          0.000000            0.000000                 0.000000
# 25%          2.000000            1.000000                 3.000000
# 50%          4.000000            2.000000                 6.000000
# 75%          7.000000            3.000000                10.000000
# max       1386.000000          568.000000              1998.000000
#
#        Total of Valid\rVotes  No of\rrejected\rvotes          Total  \
# count             236.000000                     3.0     236.000000
# mean             1916.991525                     0.0    1916.991525
# std             13795.464866                     0.0   13795.464866
# min                17.000000                     0.0      17.000000
# 25%               469.000000                     0.0     469.000000
# 50%               634.000000                     0.0     634.000000
# 75%               805.750000                     0.0     805.750000
# max            150809.000000                     0.0  150809.000000
#
#        No of\rtendered\rvotes
# count                     3.0
# mean                      0.0
# std                       0.0
# min                       0.0
# 25%                       0.0
# 50%                       0.0
# 75%                       0.0
# max                       0.0

# %%
print(f"Missing Values :\n{df.isnull().sum()}")
# Out:
# Missing Values :
# SL.NO. OF\rPOLLING\rSTATIONS      0
# AJIT\nMANGARAJ\INC                0
# PRADEEP\nMAHARATHY\BJD\n          0
# JUDHISTIR\nSAMANTARA\nY\INC       0
# ASHOK\nPRADHAN\BJP                0
# SUDARSHAN\nPRADHAN\SP             0
# SHYAM\rSUNDAR\rCHHOTRYA           0
# Total of Valid\rVotes             0
# No of\rrejected\rvotes          233
# Total                             0
# No of\rtendered\rvotes          233
# dtype: int64
